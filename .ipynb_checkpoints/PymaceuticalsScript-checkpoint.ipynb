# %% [markdown]
# # __Observations and Insights__

# %% [markdown]
# ### Pymaceuticals Inc. Squamous Cell Carcinoma Study Analysis
# Through analyzing the study data of 249 mice identified with SCC tumor growth and treated with 10 drug regimen treatments including a placebo, a few trends are outlined.
#
#
# #### Obserable Trends
# 1. Capomuin and Ramicane are the top two most promising drug regimen treatments in this study. They both has the largest number of mice survive with the smallest tumor volume, and have the least variance among the ten treatments.
#
# 2. Infubionol and Propriva results seem average based on the summary statistics, but when considering the number of mice who died by the end of the study these two had less surviving mice than even the placebo.
#
# 3. Though Zoniferol and Ceftamin were considered in the top four most promising, for mice that survived through the end of the study 30-38% less mice were alive than Capomulin and Ramicane and the tumor volume sizes are 44-48% larger.

# %%
#import library dependencies and setup file
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from scipy.stats import linregress


#research study files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

#read research data to analyze the study results
mouse_data = pd.read_csv(mouse_metadata)
results = pd.read_csv(study_results)

#Combine the data tables into a single dataset
pyarm_data = pd.merge(mouse_data, results, how="left", on=["Mouse ID","Mouse ID"])

# %%
#Calculate the number of mice in the DataFrame, which is 249
mice = len(pyarm_data["Mouse ID"].unique())

# %%
#Calculate the duplicate mice by ID number that shows up for Mouse ID and Timepoint, which is 1893
timepoints = pyarm_data["Mouse ID"].count()

# %%
#Find all the data for the duplicate mouse ID, which is "g989"
duplicate = pyarm_data.loc[pyarm_data.duplicated(subset=['Mouse ID', 'Timepoint',]),'Mouse ID'].unique()

# %%
#Build DataFrame by dropping the duplicate mouse by its ID, which is 1880
study = pyarm_data[pyarm_data['Mouse ID'].isin(duplicate)==False]

# %%
#Find the number of mice in the clean DataFrame, which is 1880
micecount = study["Mouse ID"].count()

# %% [markdown]
# ## __Summary Statistics__

# %%
#Calculalte and place mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
study_summary = study.groupby('Drug Regimen').agg(Mean=('Tumor Volume (mm3)','mean'),
                                                  Median=('Tumor Volume (mm3)','median'),
                                                  Variance=('Tumor Volume (mm3)','var'),
                                                  StandardDeviation=('Tumor Volume (mm3)','std'),
                                                  SEM=('Tumor Volume (mm3)','sem'))

#rename column and update format of summary statistics table
study_summary.rename(columns={'StandardDeviation':'Standard Deviation'}).style.set_properties(**{'text-align':'center'}).set_table_styles([
    {'selector': 'th','props':[('text-align','left')]},
    {'selector': '.col_heading','props':[('text-align','left')]},
    {'selector': '.row_heading','props':[('text-align','left')]}])
# Out:
# <style  type="text/css" >
#     #T_c7e39b58_6b5d_11eb_92f8_acde48001122 th {
#           text-align: left;
#     }    #T_c7e39b58_6b5d_11eb_92f8_acde48001122 .col_heading {
#           text-align: left;
#     }    #T_c7e39b58_6b5d_11eb_92f8_acde48001122 .row_heading {
#           text-align: left;
# ...

# %% [markdown]
# ## __Bar Plots__

# %%
#Find data for bar plot on the number of mice per point for each treatment
zero = study[study['Timepoint'] == 0].groupby('Drug Regimen').count()['Mouse ID']
five = study[study['Timepoint'] == 5].groupby('Drug Regimen').count()['Mouse ID']
ten = study[study['Timepoint'] == 10].groupby('Drug Regimen').count()['Mouse ID']
fifteen = study[study['Timepoint'] == 15].groupby('Drug Regimen').count()['Mouse ID']
twenty = study[study['Timepoint'] == 20].groupby('Drug Regimen').count()['Mouse ID']
twentyfive = study[study['Timepoint'] == 25].groupby('Drug Regimen').count()['Mouse ID']
thirty = study[study['Timepoint'] == 30].groupby('Drug Regimen').count()['Mouse ID']
thirtyfive = study[study['Timepoint'] == 35].groupby('Drug Regimen').count()['Mouse ID']
forty = study[study['Timepoint'] == 40].groupby('Drug Regimen').count()['Mouse ID']
fortyfive = study[study['Timepoint'] == 45].groupby('Drug Regimen').count()['Mouse ID']
timepoint_total = study.groupby('Drug Regimen').count()['Mouse ID']

# %%
#Create dataframe of data
bar = pd.DataFrame({"0":zero,
                    "5":five,
                    "10":ten,
                    "15":fifteen,
                    "20":twenty,
                    "25":twentyfive,
                    "30":thirty,
                    "35":thirtyfive,
                    "40":forty,
                    "45":fortyfive,
                    "Total":timepoint_total})

# %%
#Timepoints per treatment drug regimen check
plot = study.groupby(["Drug Regimen"]).count()["Mouse ID"]

# %%
#Drug regimen mice count by timepoint check
counted = study.groupby(["Drug Regimen","Timepoint"]).size()

# %%
#Drug regimen mice count by timepoint check in dataframe
time = study.groupby(["Drug Regimen","Timepoint"])
time_table = pd.DataFrame(time.size())

# %%
#Remove Total column
del bar['Total']

#Create Pandas Bar Plot on the number of mice per timepoint for each drug regimen treatment
ax = bar.plot.bar(rot=0,figsize=(20,8))
plt.title("Pyma Study: Mice per Treatment at each Timepoint")
plt.ylabel("Alive Mice")
plt.legend(title="Days",loc='center left',bbox_to_anchor=(1.0,0.5))

#Save Pandas Bar Plot
plt.tight_layout()
plt.savefig("Images/pandas_bar_plot.png")
plt.show()

# %%
#Create Pyplot Bar Plot on the number of mice per timepoint for each drug regimen treatment
fig, ax = plt.subplots(figsize=(20,8))
xaxis = np.arange(len(bar))
barwidth = 0.08

for i, col in enumerate(bar.columns):
    plt.bar(xaxis+(-0.5+i*barwidth),bar[col],width=barwidth,label=col)

#Rename x axis data to drug regimen treatments
treatments = [value for value in xaxis]
plt.xticks(treatments, ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'])

#Format Pyplot Bar Plot
plt.title("Pyma Study: Mice per Treatment at each Timepoint")
plt.ylabel("Alive Mice")
plt.xlabel("Drug Regimen")
plt.legend(title="Days",loc='center left',bbox_to_anchor=(1.0,0.5))
plt.tight_layout()
plt.savefig("Images/pyplot_bar_plot.png")
plt.show()

# %% [markdown]
# ## __Pie Plots__

# %%
#Calculate number of unique mice, which is 248
uniquemice = study["Mouse ID"].nunique()

# %%
#Pull mice and sex data for pie plots
sex = study.groupby(["Mouse ID","Sex"])
sex_table = pd.DataFrame(sex.size())

# %%
#Calculate unique mice's sex
study_gender = pd.DataFrame(sex_table.groupby(["Sex"]).count())
study_gender.columns = ["Mice Count"]

#Calculate and place unique mice's sex percentage
study_gender["Percentage"] = ((study_gender["Mice Count"]/uniquemice)*100) 
study_gender["Percentage"] = study_gender["Percentage"]

# %%
#Create and format a pie plot of study gender data using pandas
colors = ['yellow','orange']
explode = (0.1,0)
pieplot = study_gender.plot.pie(y='Mice Count',
                                figsize=(14,7),colors = colors,startangle=45,
                                explode = explode, shadow=True, autopct="%1.1f%%")
plt.title('Pyma Study Mice: Sex',fontsize = 20)
plt.ylabel('',fontsize = 16)
plt.legend(title="Sex")

#Save Pandas Pie Plot
plt.tight_layout()
plt.savefig("Images/pandas_pie_plot.png")
plt.show()

# %%
#Create and format a pie plot of study gender data using pyplot
labels = ["Female","Male"]
fig, ax2 = plt.subplots(figsize=(14,7))
ax2.pie(study_gender["Percentage"],labels=labels, colors=colors, shadow=True, explode=explode, startangle=45, autopct='%1.1f%%')
plt.title('Pyma Study Mice: Sex',fontsize = 20)
plt.ylabel('',fontsize = 16)
plt.legend(title="Sex")


#Save Pyplot Pie Plot
plt.tight_layout()
plt.savefig("Images/pyplot_pie_plot.png")
plt.show()

# %% [markdown]
# ## __Quartiles, Outliers and Boxplots__

# %%
#Distinguish the most promising treatment by finding the number of alive mice at timepoint 45 per drug regimen
time45_drug = study[study['Timepoint'] == 45].groupby('Drug Regimen').count()['Mouse ID']

#Distinguish the most promising treatment by finding the average size of tumors at timepoint 45 per drug regimen
time45_tumor = study[study['Timepoint'] == 45].groupby('Drug Regimen').mean()['Tumor Volume (mm3)']

#Combine and print data into one dataset
tumor_data = pd.merge(time45_drug, time45_tumor, how="left", on=["Drug Regimen"])

# %%
#Find treatments with the most living mice at the end of the study, which are Capomulin, Ramicane, Zoniferol, Ceftamin
topliving = tumor_data.sort_values(by='Mouse ID', ascending=False).head(4)

# %%
#Find treatments with the smallest tumors at the end of the study, which are Ramicane, Capomulin, Ceftamin, Infubinol
smallesttumors = tumor_data.sort_values(by='Tumor Volume (mm3)').head(4)

# %% [markdown]
# ### _The four from 'topliving' will be used as the most promising treatments because the difference in living mice is greater than the difference in the smallest tumor volume amongst the lists._

# %%
#Filter original research data for top four treatments data
topliving_data = study[study["Drug Regimen"].isin(["Capomulin", "Ramicane", "Zoniferol", "Ceftamin"])]

#Calculate number of mice still living at timepoint 45, which is 68 and matches above totals
topliving_filter = topliving_data[topliving_data['Timepoint']== 45]

#Create new dataframe with only data on top four treamtments, all mice treated by them, the timepoints, and their tumor sizes
topliving_table = topliving_data[["Drug Regimen","Mouse ID","Timepoint","Tumor Volume (mm3)"]]

# %%
#Filter new dataframe for last tumor volume of each mouse treated by the top four treatments
topliving_last = topliving_table.groupby(['Drug Regimen','Mouse ID']).last()['Tumor Volume (mm3)']
toptreatment = topliving_last.to_frame()
topdata = toptreatment.reset_index()

# %%
#For Capomulin treated mice calculate and print the InterQuartile Range ("IQR") and Quantitatively determine if any outliers are present
capomulin = topdata.loc[topdata['Drug Regimen']=='Capomulin']['Tumor Volume (mm3)']
capo_iqr = capomulin.quantile([.25,.5,.75])
capo_lower = capo_iqr[.25]
capo_upper = capo_iqr[.75]
capo_quart = capo_upper-capo_lower
capo_lowerout = capo_lower-(1.5*capo_quart)
capo_upperout = capo_upper+(1.5*capo_quart)
print(f"For the Capomulin treatment, the lower quartile is: {capo_lower}")
print(f"For the Capomulin treatment, the upper quartile is: {capo_upper}")
print(f"For the Capomulin treatment, the interquartile range is: {capo_quart}")
print(f"For the Capomulin treatment, the median of temperatures is: {capo_iqr[0.5]}")
print(f"For the Capomulin treatment, any number below {round(capo_lowerout, 2)} is considerd an outlier")
print(f"For the Capomulin treatment, any number above {round(capo_upperout, 2)} is considerd an outlier")
# Out:
# For the Capomulin treatment, the lower quartile is: 32.37735684
# For the Capomulin treatment, the upper quartile is: 40.1592203
# For the Capomulin treatment, the interquartile range is: 7.781863460000004
# For the Capomulin treatment, the median of temperatures is: 38.125164399999996
# For the Capomulin treatment, any number below 20.7 is considerd an outlier
# For the Capomulin treatment, any number above 51.83 is considerd an outlier

# %%
#For Ramicane treated mice calculate and print the InterQuartile Range ("IQR") and Quantitatively determine if any outliers are present
ramicane = topdata.loc[topdata['Drug Regimen']=='Ramicane']['Tumor Volume (mm3)']
rami_iqr = ramicane.quantile([.25,.5,.75])
rami_lower = rami_iqr[.25]
rami_upper = rami_iqr[.75]
rami_quart = rami_upper-rami_lower
rami_lowerout = rami_lower-(1.5*rami_quart)
rami_upperout = rami_upper+(1.5*rami_quart)
print(f"For the Ramicane treatment, the lower quartile is: {rami_lower}")
print(f"For the Ramicane treatment, the upper quartile is: {rami_upper}")
print(f"For the Ramicane treatment, the interquartile range is: {rami_quart}")
print(f"For the Ramicane treatment, the median of temperatures is: {rami_iqr[0.5]}")
print(f"For the Ramicane treatment, any number below {round(rami_lowerout, 2)} is considerd an outlier")
print(f"For the Ramicane treatment, any number above {round(rami_upperout, 2)} is considerd an outlier")
# Out:
# For the Ramicane treatment, the lower quartile is: 31.56046955
# For the Ramicane treatment, the upper quartile is: 40.65900627
# For the Ramicane treatment, the interquartile range is: 9.098536719999998
# For the Ramicane treatment, the median of temperatures is: 36.56165229
# For the Ramicane treatment, any number below 17.91 is considerd an outlier
# For the Ramicane treatment, any number above 54.31 is considerd an outlier

# %%
#For Zoniferol treated mice calculate and print the InterQuartile Range ("IQR") and Quantitatively determine if any outliers are present
zoniferol = topdata.loc[topdata['Drug Regimen']=='Zoniferol']['Tumor Volume (mm3)']
zoni_iqr = zoniferol.quantile([.25,.5,.75])
zoni_lower = zoni_iqr[.25]
zoni_upper = zoni_iqr[.75]
zoni_quart = zoni_upper-zoni_lower
zoni_lowerout = zoni_lower-(1.5*zoni_quart)
zoni_upperout = zoni_upper+(1.5*zoni_quart)
print(f"For the Zoniferol treatment, the lower quartile is: {zoni_lower}")
print(f"For the Zoniferol treatment, the upper quartile is: {zoni_upper}")
print(f"For the Zoniferol treatment, the interquartile range is: {zoni_quart}")
print(f"For the Zoniferol treatment, the median of temperatures is: {zoni_iqr[0.5]}")
print(f"For the Zoniferol treatment, any number below {round(zoni_lowerout, 2)} is considerd an outlier")
print(f"For the Zoniferol treatment, any number above {round(zoni_upperout, 2)} is considerd an outlier")
# Out:
# For the Zoniferol treatment, the lower quartile is: 49.98830246
# For the Zoniferol treatment, the upper quartile is: 66.79415599
# For the Zoniferol treatment, the interquartile range is: 16.805853529999993
# For the Zoniferol treatment, the median of temperatures is: 61.84005842
# For the Zoniferol treatment, any number below 24.78 is considerd an outlier
# For the Zoniferol treatment, any number above 92.0 is considerd an outlier

# %%
#For Ceftamin treated mice calculate and print the InterQuartile Range ("IQR") and Quantitatively determine if any outliers are present
ceftamin = topdata.loc[topdata['Drug Regimen']=='Ceftamin']['Tumor Volume (mm3)']
ceft_iqr = ceftamin.quantile([.25,.5,.75])
ceft_lower = ceft_iqr[.25]
ceft_upper = ceft_iqr[.75]
ceft_quart = ceft_upper-ceft_lower
ceft_lowerout = ceft_lower-(1.5*ceft_quart)
ceft_upperout = ceft_upper+(1.5*ceft_quart)
print(f"For the Ceftamin treatment, the lower quartile is: {ceft_lower}")
print(f"For the Ceftamin treatment, the upper quartile is: {ceft_upper}")
print(f"For the Ceftamin treatment, the interquartile range is: {ceft_quart}")
print(f"For the Ceftamin treatment, the median of temperatures is: {ceft_iqr[0.5]}")
print(f"For the Ceftamin treatment, any number below {round(ceft_lowerout, 2)} is considerd an outlier")
print(f"For the Ceftamin treatment, any number above {round(ceft_upperout, 2)} is considerd an outlier")
# Out:
# For the Ceftamin treatment, the lower quartile is: 48.72207785
# For the Ceftamin treatment, the upper quartile is: 64.29983003
# For the Ceftamin treatment, the interquartile range is: 15.577752179999997
# For the Ceftamin treatment, the median of temperatures is: 59.85195552
# For the Ceftamin treatment, any number below 25.36 is considerd an outlier
# For the Ceftamin treatment, any number above 87.67 is considerd an outlier

# %%
#Create and Format the Boxplot for top four treatments
fig1, ax = plt.subplots(figsize=(15,10))
ax.set_title('Top Mice Treatments: Tumor Volume',fontsize =25)
ax.set_ylabel('Last Tumor Volume (mm3)',fontsize = 16)
ax.set_xlabel('Drug Regimen Treatments',fontsize = 16)
iqr_drugs = ['Capomulin','Ramicane','Zoniferol','Ceftamin']
iqr_data = toptreatment.reset_index()
iqr_tumor = iqr_data.groupby('Drug Regimen')['Tumor Volume (mm3)'].apply(list)
iqr = pd.DataFrame(iqr_tumor)
iqr = iqr.reindex(iqr_drugs)
iqr_volume = [vol for vol in iqr['Tumor Volume (mm3)']]
plt.boxplot(iqr_volume,
            labels=iqr_drugs,
            widths = 0.4,
            boxprops={"facecolor":"pink"},
            capprops={"color":"gray"},
            whiskerprops={"color":"magenta","linestyle":'--'},
            flierprops={"color":"purple","markeredgecolor":"grey"},
            medianprops={"color":"yellow"},
            patch_artist=True, vert=True)
plt.ylim(10,80)

#Save Boxplot
plt.tight_layout()
plt.savefig("Images/boxplot.png")
plt.show()

# %% [markdown]
# ## __Line and Scatter Plots__

# %%
#Find mouse treated with Capomulin with a final tumor volume closest to the average of 36.24, mouse identified is w914
linedata = topdata.loc[topdata['Drug Regimen']=='Capomulin']

# %%
#Filter original research data for Capomulin treatments data
capomulin_data = study[study["Drug Regimen"].isin(["Capomulin"])]

#Filter Capomulin data for mouse w914
capomulin_mouse = capomulin_data[capomulin_data['Mouse ID']== 'w914']

#Create new dataframe of timepoints and tumor sizes for mouse w914 that was treated with Capomulin
capomulin_table = capomulin_mouse[["Timepoint","Tumor Volume (mm3)"]]

# %%
#Create and format a line plot of timepoints and tumor sizes for mouse w914 that was treated with Capomulin
fig3, line = plt.subplots(figsize=(15,10))
line = plt.plot(capomulin_table["Timepoint"],capomulin_table["Tumor Volume (mm3)"],markersize=16,marker="o",color='green')
plt.title("Capomulin Study w914: Tumor Volume (mm3) over Time",fontsize=25)
plt.ylabel("Tumor Volume (mm3)",fontsize=16)
plt.xlabel("Days",fontsize=16)

#Save Line Plot
plt.tight_layout()
plt.savefig("Images/lineplot.png")
plt.show()

# %%
#Filter new dataframe for weight and average tumor volume of each mouse treated by Capomulin
scatterdata = capomulin_data.groupby(['Mouse ID','Weight (g)']).mean()['Tumor Volume (mm3)']
weight_volume = scatterdata.to_frame()
averagedata = weight_volume.reset_index()

# %%
#Create and format a scatter plot of weight and average tumor size of each mouse treated with Capomulin
fig4, scatter = plt.subplots(figsize=(15,10))
scatter = plt.scatter(averagedata["Weight (g)"],averagedata["Tumor Volume (mm3)"],color="orange",s=150,edgecolor="blue")
plt.title("Capomulin Study Mice: Weight & Avg. Tumor Volume (mm3)",fontsize=25)
plt.ylabel("Tumor Volume (mm3)",fontsize=16)
plt.xlabel("Weight",fontsize=16)

#Save Line Plot
plt.tight_layout()
plt.savefig("Images/scatterplot.png")
plt.show()

# %% [markdown]
# ## __Correlation and Regression__

# %%
# Calculate and print the correlation coefficient of the linear regression model 
(slope, intercept,rvalue, pvalue, stderr)= linregress(averagedata["Weight (g)"],averagedata["Tumor Volume (mm3)"])
regressionline = averagedata["Weight (g)"]* slope + intercept
line = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
print(f"The slope is: {slope}")
print(f"The intercept is: {intercept}")
print(f"The correlation coefficient is: {round(rvalue,2)}")
print(f"The p-value is: {pvalue}")
print(f"The standard error is: {stderr}")
print(f"The intercept is:{intercept}")
print(f"The regression line equation is: {line}")
# Out:
# The slope is: 0.9544396890241045
# The intercept is: 21.552160532685015
# The correlation coefficient is: 0.84
# The p-value is: 1.3225722434712642e-07
# The standard error is: 0.1275435903320134
# The intercept is:21.552160532685015
# The regression line equation is: y = 0.95 x + 21.55

# %%
#Create and format a regression line model of weight and average tumor size of each mouse treated with Capomulin
fig5, regression = plt.subplots(figsize=(15,10))
regression = plt.scatter(averagedata["Weight (g)"],averagedata["Tumor Volume (mm3)"],color="orange",s=150,edgecolor="blue")
plt.plot(averagedata["Weight (g)"],regressionline, color='blue')
plt.annotate(line,(23,35),color='blue',fontsize=16)
plt.title("Capomulin Study Mice: Weight & Avg. Tumor Volume (mm3)",fontsize=25)
plt.ylabel("Tumor Volume (mm3)",fontsize=16)
plt.xlabel("Weight",fontsize=16)

#Save Line Plot
plt.tight_layout()
plt.savefig("Images/regression.png")
plt.show()
